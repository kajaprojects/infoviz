# %%
import pandas as pd
import numpy as np
import panel as pn
import plotly.express as px
pn.extension('tabulator')
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objects as go
import panel.widgets as pnw
import hvplot.pandas
#from bokeh.plotting import figure
#from panel.template.theme import Theme
#from bokeh.themes import DARK_MINIMAL
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6c8ba97e-2cc0-40b8-b381-faed964cfc73'>
#   <div id="ab9d4aee-4578-47f3-a736-6712367c987f" data-root-id="6c8ba97e-2cc0-40b8-b381-faed964cfc73" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df_h = pd.read_csv('C:\\Users\\Kaja\\Desktop\\infoviz\\data\\olympic_hosts.csv')
df = pd.read_csv('C:\\Users\\Kaja\\Desktop\\infoviz\\data\\olympic_results.csv')

# %%
df
# Out:
#            discipline_title  \
# 0                   Curling
# 1                   Curling
# 2                   Curling
# 3                   Curling
# 4                   Curling
# ...                     ...
# 162799          Ski Jumping
# 162800          Ski Jumping
# 162801          Ski Jumping
# 162802          Ski Jumping
# 162803  Gymnastics Artistic
#
#                                               event_title      slug_game  \
# 0                                           Mixed Doubles   beijing-2022
# 1                                           Mixed Doubles   beijing-2022
# 2                                           Mixed Doubles   beijing-2022
# 3                                           Mixed Doubles   beijing-2022
# 4                                           Mixed Doubles   beijing-2022
# ...                                                   ...            ...
# 162799                         Normal Hill Individual men  chamonix-1924
# ...

# %%
df = df.fillna(0)
idf = df.interactive()

df_h = df_h.fillna(0)
df_h = df_h[df_h['game_location'] != 0] 

#getting a date from slug_game
df['date'] = df['slug_game'].str.split('-').str[-1]
df['date'] = df['date'].str.strip()

#group by types of medals per year
df2 = df
worldmap1 = df.groupby(['date','country_name', 'medal_type']).size().reset_index(name='counts')
worldmap1 = worldmap1[worldmap1['medal_type'] != 0] 
#vis3 dataframe
disc_df = df.groupby(['date', 'discipline_title','country_name', 'medal_type']).size().reset_index(name='counts')
disc_dfx = disc_df[disc_df['medal_type'] != 0] 

#new df for second vis so it's not slow
disc_df2 = df.groupby(['date', 'discipline_title','country_name', 'medal_type']).size().reset_index(name='counts')
disc_dfx2 = disc_df[disc_df['medal_type'] != 0] 
#worldmap.head
worldmapx = worldmap1[worldmap1['medal_type'] != 0]
# df with sum of all medals by country and date
worldmap = worldmap1.groupby(['date','country_name']).size().reset_index(name='sum_of_medals')
#worldmap['gold'] = worldmap1['medal_type'] == 'GOLD'

worldmap

#df for slovenia
slovenia_df = worldmapx[worldmapx['country_name'] == 'Slovenia']
slovenia_df

#slovenia_df['gold_medals'] = slovenia_df['counts'].where(['medal_type']=='GOLD', slovenia_df['medal_type'])
slovenia_df.loc[slovenia_df['medal_type'] == 'GOLD', 'gold_medal'] = slovenia_df['counts']
slovenia_df['gold_medal'].fillna(0, inplace=True)
slovenia_df.loc[slovenia_df['medal_type'] == 'SILVER', 'silver_medal'] = slovenia_df['counts']
slovenia_df['silver_medal'].fillna(0, inplace=True)
slovenia_df.loc[slovenia_df['medal_type'] == 'BRONZE', 'bronze_medal'] = slovenia_df['counts']
slovenia_df['bronze_medal'].fillna(0, inplace=True)


radio_group_color = pn.widgets.RadioBoxGroup(name='color combination', options=['Blue', 'Red', 'Black', 'Green', 'Yellow'], inline=True)
@pn.depends(radio_group_color.param.value)
def get_color(selected_option):
    if selected_option == 'Red':
        return 'red'
    elif selected_option == 'Blue':
        return 'blue'
    elif selected_option == 'Black':
        return 'black'
    elif selected_option == 'Green':
        return 'green'
    elif selected_option == 'Yellow':
        return 'yellow'



#option=get_color
option = get_color(radio_group_color.value)
def set_color_map(option):
    if option == 'blue':
        return px.colors.sequential.Blues 
    elif option == 'red':
        return px.colors.sequential.Reds 
    elif option == 'black':
        return px.colors.sequential.Greys   
    elif option == 'green':
        return px.colors.sequential.Greens 
    elif option == 'yellow':
        return px.colors.sequential.Darkmint #Solar   
    
def create_map():
    option = get_color(radio_group_color.value)
    color_scale = set_color_map(option)
    fig= px.choropleth(
        worldmap,
        locations="country_name",
        locationmode='country names',
        color='sum_of_medals',
        hover_data='sum_of_medals', 
        animation_frame='date',
        title="Olympics Medal timelapse",
        color_continuous_scale=color_scale,
        width = 1500,
        height = 1200)
    return fig 

option = get_color(radio_group_color.value)
def set_color_map(option):
    if option == 'blue':
        return px.colors.sequential.Blues 
    elif option == 'red':
        return px.colors.sequential.Reds 
    elif option == 'black':
        return px.colors.sequential.Greys   
    elif option == 'green':
        return px.colors.sequential.Greens 
    elif option == 'yellow':
        return px.colors.sequential.Darkmint #Solar  
        
def create_map2():
    option = get_color(radio_group_color.value)
    color_scale = set_color_map(option)
    fig= px.choropleth(
        df_h,
        locations="game_location",
        locationmode='country names',
      #  color=px.colors.sequential.Greens ,
      #  hover_data='sum_of_medals', 
        animation_frame='game_year',
        title="Olympic host countries",
    #    color_continuous_scale=color_scale,
        width = 1500,
        height = 1200)
    return fig 
#create_map2()


pn.extension('plotly')
country = list(df.country_name.unique())
select = pn.widgets.Select(name='Select Country', options=country)

#filtered_data = worldmap1.interactive()
#filtered_data = worldmap1[worldmap1['country_name'] == select]
#filtered_data.head()



def create_histogram():
#    filtered_data = worldmap1[worldmap1['country_name'] == select]
    idf = worldmap1.interactive()
    idf = idf[(idf["country_name"] == country_widget)]
    fig = px.histogram(filtered_data, x="date", y="counts", color="medal_type").update_xaxes(categoryorder="category ascending")
    return fig


country = list(df.country_name.unique())
country_widget = pn.widgets.Select(name="country_name", options=country)

def create_plot():
    text = 'Choose visualization for medal results'
    idf = disc_dfx.interactive()
    idf = idf[(idf["country_name"] == country_widget)] #& (idf["discipline_title"] == discipline_widget)
    idf.head()
    second = idf.hvplot(kind="bar", x="discipline_title", y="counts", color = "medal_type", cmap=['blue', 'orange', 'red'])
    return second


discipline = list(df2.discipline_title.unique())
discipline_widget = pn.widgets.Select(name="discipline_title", options=discipline)

def create_plot_date():
    idf = disc_dfx2.interactive()
    idf = idf[(idf["country_name"] == country_widget) & (idf["discipline_title"] == discipline_widget)]
    idf.head()
    third = idf.hvplot(kind="bar", x="date", y="counts", color = "medal_type", cmap=['blue', 'red', 'orange'])
    return third
# Out:
# C:\Users\Kaja\AppData\Local\Temp\ipykernel_1564\416715559.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slovenia_df.loc[slovenia_df['medal_type'] == 'GOLD', 'gold_medal'] = slovenia_df['counts']
# C:\Users\Kaja\AppData\Local\Temp\ipykernel_1564\416715559.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slovenia_df['gold_medal'].fillna(0, inplace=True)
# C:\Users\Kaja\AppData\Local\Temp\ipykernel_1564\416715559.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#medals = list(df.medal_type.unique())
#select1 = pn.widgets.Select(name='Select medal', medals)
#select1
slovenia_df
# Out:
#       date country_name medal_type  counts  gold_medal  silver_medal  \
# 3259  1992     Slovenia     BRONZE       2         0.0           0.0
# 3404  1994     Slovenia     BRONZE       3         0.0           0.0
# 3717  1996     Slovenia     SILVER       2         0.0           2.0
# 4204  2000     Slovenia       GOLD       2         2.0           0.0
# 4378  2002     Slovenia     BRONZE       1         0.0           0.0
# 4698  2004     Slovenia     BRONZE       3         0.0           0.0
# 4699  2004     Slovenia     SILVER       1         0.0           1.0
# 5220  2008     Slovenia     BRONZE       2         0.0           0.0
# 5221  2008     Slovenia       GOLD       1         1.0           0.0
# 5222  2008     Slovenia     SILVER       2         0.0           2.0
# 5416  2010     Slovenia     BRONZE       1         0.0           0.0
# 5417  2010     Slovenia     SILVER       2         0.0           2.0
# 5754  2012     Slovenia     BRONZE       2         0.0           0.0
# ...

# %%
#year_slider = pn.widgets.EditableIntSlider(name='Year', start=1992, end=2022, step=2, value=1992)
#df_athlet = df.groupby(['date','athlete_full_name', 'country_name', 'medal_type']).size().reset_index(name='counts')
#df_athletx = df_athlet[df_athlet['athlete_full_name'] != 0] 
#disc_df = df.groupby(['date', 'discipline_title','country_name', 'medal_type']).size().reset_index(name='counts')
#disc_dfx = disc_df[disc_df['medal_type'] != 0] 
df = df.fillna(0)
df_athlet = df.groupby(['date', 'discipline_title', 'athlete_full_name', 'country_name', 'medal_type']).size().reset_index(name='counts')
df_athletx = df_athlet[df_athlet['athlete_full_name'] != 0] 
df_athletx = df_athletx[df_athlet['medal_type'] != 0] 
df_athletx
# Out:
# C:\Users\Kaja\AppData\Local\Temp\ipykernel_1564\2371359703.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#         date discipline_title  athlete_full_name                country_name  \
# 3       1896        Athletics    Alajos SZOKOLYI                     Hungary
# 4       1896        Athletics       Albert TYLER    United States of America
# 6       1896        Athletics   Albin LERMUSIAUX                      France
# 8       1896        Athletics  Alexandre TUFFERI                      France
# 15      1896        Athletics       Arthur BLAKE    United States of America
# ...      ...              ...                ...                         ...
# 124443  2022    Speed skating     Seung Hoon LEE           Republic of Korea
# 124452  2022    Speed skating        Thomas KROL                 Netherlands
# 124453  2022    Speed skating        Thomas KROL                 Netherlands
# ...

# %%
year_slider = pn.widgets.IntSlider(name='Year - medals Slovenia', start=1992, end=2022, step=2, value=2004)
df_athletx["date_int"] = pd.to_numeric(df_athletx["date"])
slovenia_dfi = df_athletx.interactive()
slovenia_dfi = slovenia_dfi[slovenia_dfi['country_name'] == 'Slovenia']

slovenia_dfi = slovenia_dfi[(slovenia_dfi["date_int"] == year_slider)] #& (idf["discipline_title"] == discipline_widget)
slovenia_dfi.head()
slovenia_dfi
# Out:
# <div id='1f9cd964-27aa-4e91-8886-e38380ad30fc'>
#   <div id="d647c6d4-1939-44f3-90b2-4d5a1bfebd3a" data-root-id="1f9cd964-27aa-4e91-8886-e38380ad30fc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
#df_athlet = df.groupby(['date','athlete_full_name', 'country_name', 'medal_type']).size().reset_index(name='counts')
#df_athlet = df_athlet[df_athlet['medal_type'] != 0] 

#slovenia_dfi = df_athletx.interactive()
#slovenia_dfi = slovenia_dfi[(slovenia_dfi["date"] == '2000')] #& (idf["country_name"] == "Slovenia")
#slovenia_dfi.head()


#plot_slo = slovenia_dfi.hvplot(kind="bar", x="country_name", y="counts", color = "medal_type", cmap=['blue', 'orange', 'red'])
plot_slo = slovenia_dfi.hvplot(kind="bar", x="athlete_full_name", y="counts", color = "medal_type", cmap=['blue', 'orange', 'red'])
#plot_slo = slovenia_dfi.hvplot(kind="bar", x="discipline_title", y="counts", color = "medal_type", cmap=['blue', 'orange', 'red'])
#plot_slo = slovenia_dfi.hvplot(kind="bar", x="date", y="counts", color = "medal_type", cmap=['blue', 'orange', 'red'])
plot_slo
# Out:
# <div id='58069c1b-b5c3-4b85-9b8f-7e069b079086'>
#   <div id="b1249328-0dea-4cb7-927a-59ba6dc41aa0" data-root-id="58069c1b-b5c3-4b85-9b8f-7e069b079086" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
#@pn.depends(year.param.value) 
def create_plot_slo():
    text = 'Choose visualization for medal results'
    df_athletx["date_int"] = pd.to_numeric(df_athletx["date"])
    slovenia_dfi = df_athletx.interactive()
    slovenia_dfi = slovenia_dfi[slovenia_dfi['country_name'] == 'Slovenia']

    slovenia_dfi = slovenia_dfi[(slovenia_dfi["date_int"] == year_slider)] #& (idf["discipline_title"] == discipline_widget)
    slovenia_dfi.head()
    plot_slo = slovenia_dfi.hvplot(kind="bar", x="athlete_full_name", y="counts", color = "medal_type", cmap=['blue', 'orange', 'red'])
    return plot_slo

# %%
radio_group = pn.widgets.RadioBoxGroup(name='Olympic medals visualization', options=[ 'By Country','Map', 'By Discipline', 'By Athlets'], inline=True)

# %%
text = 'Choose visualization for medal results'
text_med = 'Olympic results'
text2 = 'Choose visualization for Olympic games hosts'

text_color = 'Pick color combination for map'
text_color2 = 'Pick color combination for visualization by country'

# %%
png_pane = pn.pane.PNG('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR_xnjnm4PXu1s264F_xK7pJv5q0yl5thNNRw&usqp=CAU')

# %%
radio_MH = pn.widgets.RadioButtonGroup(
    name='hostsalimedalje', options=['Medals', 'Hosts'], button_type='success')

# %%
@pn.depends(radio_group.param.value) 
def update_plots(selected_option):
    if selected_option == 'Map':
        return create_map()
    elif selected_option == 'By Country':
        return create_plot()
    elif selected_option == 'By Discipline':
        return create_plot_date()
    elif selected_option == 'By Athlets':
        return create_plot_slo()

# %%
@pn.depends(radio_MH.param.value) 
def update_plot(selected_option):
    radio_group.value
    if radio_MH.value == 'Medals':
        #return None
        plot = update_plots(radio_group.value)
        return plot
    elif radio_MH.value == 'Hosts':
        plot =create_map2()
        return plot
    else:
        plot = None
        return plot

# %%
template = pn.template.BootstrapTemplate(
    title='Olympic games',
    sidebar=[text, radio_group, text_color, radio_group_color]
)

# Append the plots to the main area
template.main.append(png_pane)
template.main.append(create_map2())
template.main.append(text_med)
template.main.append(update_plots)
#template.main.append(interactive_func)
#template.main.append(update_plots)
#template.main.append(update_plots_h)


template.servable()
# Out:
# BootstrapTemplate
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] BootstrapTemplateActions()
#     [browser_info] BrowserInfo(dark_mode=False, device_pixel_ratio=1.125, language='en-US', timezone='Europe/Ljubljana', timezone_offset=-120, webdriver=False)
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [1869718339728] Markdown(str)
#     [1869113539472] RadioBoxGroup(inline=True, name='Olympic medals v..., options=['By Country', ...], value='By Country')
#     [1869718949520] Markdown(str)
#     [1869220875664] RadioBoxGroup(inline=True, name='color combination', options=['Blue', 'Red', ...], value='Blue')
#     [1869113543440] PNG(str)
#     [1869719583696] Plotly(Figure)
#     [1869719455312] Markdown(str)
#     [1869718820240] ParamFunction(function, _pane=Interactive, defer_load=False)
